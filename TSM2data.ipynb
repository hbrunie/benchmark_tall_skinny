# %%
import pandas as pd
import plotly.express as px
df2 = pd.read_csv("./results_ism2.csv")
df2 = df.loc[lambda df: df['Precision'] == "Single"]
df3 = df.loc[lambda df: df['m'] == 10000]


#name = df2["m"].astype(str) + " " +df2["Precision"]
#name = df2["m"].astype(str) + " "+ df2["n"].astype(str)+ " " + df2["k"].astype(str)+ " " +df2["Precision"]


#df2.insert (0, "Name", name)

fig = px.bar(df3, x="Precision",y="CUBLAS GFLOPS", color="Speedup", title="CUBLAS against Tall-Skinny library speedup")
fig.write_html('first_figure.html', auto_open=True)

# %%
import pandas as pd
import plotly.express as px
df2 = pd.read_csv("./results_ism2.csv")
#df2 = df.loc[lambda df: df['Precision'] == "Single"]
#df3 = df.loc[lambda df: df['m'] == 10000]


#name = df2["m"].astype(str) + " " +df2["Precision"]
name = df2["m"].astype(str) + " "+ df2["n"].astype(str)+ " " + df2["k"].astype(str)+ " " +df2["Precision"]


df2.insert (0, "Name", name)

fig = px.bar(df2, x="Name", y="CUBLAS GFLOPS", color="Speedup", title="CUBLAS against Tall-Skinny library speedup")
fig.write_html('first_figure.html', auto_open=True)

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv("./results_ism2.csv")
df2 = df.loc[lambda df: df['Precision'] == "Single"]
df3 = df.loc[lambda df: df['m'] == 10000]
df5 = df3.groupby(['m', 'n','k','Precision']).mean()
#df5 = group.sum()

ax = df5.plot(kind='bar', figsize=(10,6), color="indigo", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("My Bar Plot", fontsize=22)
ax.set_ylabel("Some Heading on Y-Axis", fontsize=15);

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv("./results_ism2.csv")
df3 = df.loc[lambda df: df['Precision'] == "Single"]
#df3 = df.loc[lambda df: df['m'] == 10000]


name = df3["m"].astype(str) + " "+ df3["n"].astype(str)+ " " + df3["k"].astype(str)+ " " +df3["Precision"]
df3.insert (0, "Name", name)

fig = px.bar(df3, x="Name", y="CUBLAS GFLOPS", color="Speedup", title="CUBLAS against Tall-Skinny library speedup")
fig.write_html('first_figure.html', auto_open=True)

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv("./results_ism2.csv")
#df3 = df.loc[lambda df: df['Precision'] == "Single"]
df3 = df.loc[lambda df: df['m'] == 100000]


name = df3["m"].astype(str) + " "+ df3["n"].astype(str)+ " " + df3["k"].astype(str)+ " " +df3["Precision"]
df3.insert (0, "Name", name)

fig = px.bar(df3, x="Name", y="CUBLAS GFLOPS", color="Speedup", title="CUBLAS against Tall-Skinny library speedup")
fig.write_html('first_figure.html', auto_open=True)
